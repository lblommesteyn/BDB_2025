# %% [markdown]
# # Outcome Model Calibration
#
# Train a probabilistic model to replace the heuristic catch/incomplete/interception probabilities.

# %% [markdown]
# ## Updated Dataset & Model Notes
# - Builds nalytics/data/outcome_training.parquet automatically if missing using the latest nalytics/outputs/dacs_batch/.
# - Includes categorical feature expansions such as
# eat_route__POST, coverage tags, and EPA features used by nalytics/outcome_model.py.
# - After running the notebook, re-run python analytics/outcome_model.py --data analytics/data/outcome_training.parquet --dest analytics/models/outcome_model.joblib to keep the CLI model in sync.

# %% [markdown]
# ## Load Dataset

# %%
from pathlib import Path
import sys
import subprocess

NOTEBOOK_DIR = Path.cwd()

def resolve_repo_root(start: Path) -> Path:
    candidates = [start] + list(start.parents)
    for candidate in candidates:
        analytics_dir = candidate / 'analytics'
        if analytics_dir.is_dir():
            return candidate
        if candidate.name == 'analytics' and candidate.is_dir():
            return candidate.parent
    raise FileNotFoundError(f'Could not locate analytics/ directory when starting from {start}')

REPO_ROOT = resolve_repo_root(NOTEBOOK_DIR)
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))
print('Using analytics repo at:', REPO_ROOT)

import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss, classification_report
from sklearn.preprocessing import StandardScaler
import joblib

DATA_PATH = REPO_ROOT / 'analytics' / 'data' / 'outcome_training.parquet'
outputs_dir = REPO_ROOT / 'analytics' / 'outputs' / 'dacs_batch'
print('Dataset path:', DATA_PATH)
if not DATA_PATH.exists():
    if outputs_dir.is_dir():
        print('Dataset missing; rebuilding from', outputs_dir)
        subprocess.run([sys.executable, '-m', 'analytics.features.outcome_dataset', '--root', str(REPO_ROOT), '--outputs-dir', str(outputs_dir), '--dest', str(DATA_PATH)], check=True)
    else:
        raise FileNotFoundError(f'Missing {DATA_PATH} and outputs dir {outputs_dir}.')

data = pd.read_parquet(DATA_PATH)
print('Dataset loaded:', data.shape)
# Out:
# Using analytics repo at: c:\Users\16476\big_data_bowl
# Dataset path: c:\Users\16476\big_data_bowl\analytics\data\outcome_training.parquet
# Dataset loaded: (7676, 49)

# %%
from pathlib import Path
import os
import sys
import subprocess

REPO_GIT_URL = 'https://github.com/lblommesteyn/BDB_2025.git'
DEFAULT_CLONE_DIR = Path('/content/BDB_2025')


def _candidate_roots():
    roots = []
    for env_var in ("BDB_REPO_ROOT", "KAGGLE_DATA_ROOT"):
        val = os.environ.get(env_var)
        if val:
            roots.append(Path(val).expanduser())
    try:
        base = Path('..').resolve()
        roots.append(base)
        roots.extend(list(base.parents))
    except Exception:
        pass
    roots.extend([Path.cwd(), DEFAULT_CLONE_DIR, Path('/content/big_data_bowl')])
    kaggle_input = Path('/kaggle/input')
    if kaggle_input.exists():
        for child in kaggle_input.iterdir():
            roots.append(child)
    seen = []
    for r in roots:
        if r and r not in seen:
            seen.append(r)
    return seen


def _clone_repo_if_possible():
    try:
        DEFAULT_CLONE_DIR.parent.mkdir(parents=True, exist_ok=True)
        subprocess.run(['git','clone', REPO_GIT_URL, str(DEFAULT_CLONE_DIR)], check=True)
        return DEFAULT_CLONE_DIR
    except Exception as exc:
        print(f"[setup] Git clone attempt failed: {exc}")
        return None


def resolve_repo_root():
    for candidate in _candidate_roots():
        if not candidate:
            continue
        analytics_dir = candidate / 'analytics'
        if analytics_dir.is_dir():
            return candidate
        if candidate.name == 'analytics' and candidate.is_dir():
            return candidate.parent
    clone_dir = _clone_repo_if_possible()
    if clone_dir and (clone_dir / 'analytics').is_dir():
        return clone_dir
    raise FileNotFoundError(
        "Could not locate analytics/ directory. Set BDB_REPO_ROOT or KAGGLE_DATA_ROOT, or allow the helper to clone repo."
    )

REPO_ROOT = resolve_repo_root()
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))
print(f"Using analytics repo at: {REPO_ROOT}")

import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss, classification_report
from sklearn.preprocessing import StandardScaler
import joblib

DATA_PATH = REPO_ROOT / 'analytics' / 'data' / 'outcome_training.parquet'
print('Dataset path:', DATA_PATH)
if not DATA_PATH.exists():
    raise FileNotFoundError(f'Expected dataset at {DATA_PATH}')
data = pd.read_parquet(DATA_PATH)
print('Dataset loaded:', data.shape)
# Out:
# Using analytics repo at: C:\Users\16476\big_data_bowl
# Dataset path: C:\Users\16476\big_data_bowl\analytics\data\outcome_training.parquet
# Dataset loaded: (7676, 49)

# %% [markdown]
# ## Feature Engineering

# %%
FEATURES = [
    'dacs_final','dacs_final_lo','dacs_final_hi','coverage_intensity','dvi','bfoi',
    'prob_catch','prob_incomplete','prob_interception',
    'n_defenders','corridor_length','num_frames_output'
]
X = data[FEATURES].fillna(0.0).to_numpy(dtype=np.float32)
y = data['actual_event_id'].to_numpy(dtype=np.int64)
folds = data['fold_id'].to_numpy(dtype=np.int64)
X_train, y_train = X[folds != 0], y[folds != 0]
X_val, y_val = X[folds == 0], y[folds == 0]
scaler = StandardScaler().fit(X_train)
X_train_s = scaler.transform(X_train)
X_val_s = scaler.transform(X_val)
print('Train size', X_train.shape, 'Val size', X_val.shape)
# Out:
# Train size (6200, 12) Val size (1476, 12)

# %%
labels = [0, 1, 2]
clf = LogisticRegression(max_iter=1000, multi_class='multinomial')
clf.fit(X_train_s, y_train)
train_loss = log_loss(y_train, clf.predict_proba(X_train_s), labels=labels)
val_loss = log_loss(y_val, clf.predict_proba(X_val_s), labels=labels)
print({'train_log_loss': train_loss, 'val_log_loss': val_loss})
print(classification_report(y_val, clf.predict(X_val_s), labels=labels))
# Out:
# {'train_log_loss': 0.6387225078507125, 'val_log_loss': 0.6854162304571698}
#               precision    recall  f1-score   support
#
#            0       0.70      0.96      0.81       981
#            1       0.64      0.19      0.29       456
#            2       0.00      0.00      0.00        39
#
#     accuracy                           0.70      1476
#    macro avg       0.45      0.38      0.37      1476
# weighted avg       0.67      0.70      0.63      1476
# c:\Python310\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %% [markdown]
# ## Multinomial Logistic Regression

# %% [markdown]
# ## Persist Model

# %%
model_path = REPO_ROOT / 'analytics' / 'models' / 'outcome_model.joblib'
model_path.parent.mkdir(parents=True, exist_ok=True)
joblib.dump({'scaler': scaler, 'clf': clf, 'features': FEATURES}, model_path)
print('Saved model to', model_path)
# Out:
# Saved model to C:\Users\16476\big_data_bowl\analytics\models\outcome_model.joblib

# %% [markdown]
# ## Calibration Plots
# Add reliability diagrams per class to verify probability quality.

# %%
import matplotlib.pyplot as plt
from sklearn.calibration import calibration_curve

classes = ['catch','incomplete','interception']
val_proba = clf.predict_proba(X_val_s)
fig, axes = plt.subplots(1, 3, figsize=(15, 4))
for idx, ax in enumerate(axes):
    prob_true, prob_pred = calibration_curve((y_val == idx).astype(int), val_proba[:, idx], n_bins=10)
    ax.plot(prob_pred, prob_true, marker='o')
    ax.plot([0,1],[0,1], '--', color='gray')
    ax.set_title(f'Reliability: {classes[idx]}')
    ax.set_xlabel('Predicted')
    ax.set_ylabel('Observed')
plt.tight_layout()
plt.show()
